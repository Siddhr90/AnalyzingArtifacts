# %% [markdown]
# This Notebook compares performance of [base SNLI trained Electra Model] versus [base SNLI trained Electra Model trained on ANLI - Approach 1]

# %%
import os

# Change to a mounted drive, for example, /mnt/my_drive
os.chdir('E:\\NLP\\Comparison')

# %%
pwd
# Out:
# 'E:\\NLP\\Comparison'

# %%
ls
# Out:
#  Volume in drive E is Sid_2023
#  Volume Serial Number is E065-686B
#
#  Directory of E:\NLP\Comparison
#
# 12/04/2023  04:31 AM    <DIR>          .
# 12/04/2023  04:31 AM    <DIR>          ..
# 12/04/2023  03:22 AM           733,215 eval_predictions_a0_r1.jsonl
# 12/04/2023  03:23 AM           731,548 eval_predictions_a0_r2.jsonl
# 12/04/2023  03:24 AM           842,629 eval_predictions_a0_r3.jsonl
# 12/04/2023  03:19 AM           732,853 eval_predictions_a1_r1.jsonl
# 12/04/2023  03:18 AM           731,140 eval_predictions_a1_r2.jsonl
# 12/04/2023  03:20 AM           842,687 eval_predictions_a1_r3.jsonl
# 12/04/2023  04:23 AM         2,564,951 eval_predictions_SNLI_old_model.jsonl
# 12/04/2023  04:26 AM         2,567,693 eval_predictions_SNLI_updated_with_ANLI.jsonl
# 12/04/2023  04:21 AM         2,565,061 eval_predictions_SNLIpANLIm_SNLIval.jsonl
#                9 File(s)     12,311,777 bytes
#                2 Dir(s)  1,866,577,178,624 bytes free

# %%
import pandas as pd
df_base = pd.read_json('eval_predictions_SNLI_old_model.jsonl', lines=True)
df_base.head()
# Out:
#                                              premise  \
# 0  Two women are embracing while holding to go pa...
# 1  Two women are embracing while holding to go pa...
# 2  Two women are embracing while holding to go pa...
# 3  Two young children in blue jerseys, one with t...
# 4  Two young children in blue jerseys, one with t...
#
#                                           hypothesis  label  \
# 0  The sisters are hugging goodbye while holding ...      1
# 1                    Two woman are holding packages.      0
# 2               The men are fighting outside a deli.      2
# 3     Two kids in numbered jerseys wash their hands.      0
# 4           Two kids at a ballgame wash their hands.      1
#
#                                     predicted_scores  predicted_label
# 0  [-2.655517339706421, 4.35628080368042, -2.9564...                1
# 1  [3.999716997146606, -0.908149480819702, -3.110...                0
# 2  [-4.539059162139893, -2.610094308853149, 5.717...                2
# 3  [3.978000879287719, -1.148713946342468, -2.775...                0
# 4  [-3.37094497680664, 2.595725297927856, -0.2479...                1

# %%
import pandas as pd
df_a1 = pd.read_json('eval_predictions_SNLI_updated_with_ANLI.jsonl', lines=True)
df_a1.head()
# Out:
#                                              premise  \
# 0  Two women are embracing while holding to go pa...
# 1  Two women are embracing while holding to go pa...
# 2  Two women are embracing while holding to go pa...
# 3  Two young children in blue jerseys, one with t...
# 4  Two young children in blue jerseys, one with t...
#
#                                           hypothesis  label  \
# 0  The sisters are hugging goodbye while holding ...      1
# 1                    Two woman are holding packages.      0
# 2               The men are fighting outside a deli.      2
# 3     Two kids in numbered jerseys wash their hands.      0
# 4           Two kids at a ballgame wash their hands.      1
#
#                                     predicted_scores  predicted_label
# 0  [-4.015252590179443, 4.470546245574951, -1.911...                1
# 1  [2.888674736022949, -2.042037963867187, -0.795...                0
# 2  [-4.105733871459961, -1.17663288116455, 3.9173...                2
# 3  [1.355234861373901, -2.21549916267395, 1.08333...                0
# 4  [-2.860575914382934, -2.119940996170044, 3.986...                2

# %%
len(df_base)
# Out:
# 9842

# %%
import pandas as pd
df_a2 = pd.read_json('eval_predictions_SNLI_updated_with_ANLI.jsonl', lines=True)
df_a2.head()
# Out:
#                                              premise  \
# 0  Two women are embracing while holding to go pa...
# 1  Two women are embracing while holding to go pa...
# 2  Two women are embracing while holding to go pa...
# 3  Two young children in blue jerseys, one with t...
# 4  Two young children in blue jerseys, one with t...
#
#                                           hypothesis  label  \
# 0  The sisters are hugging goodbye while holding ...      1
# 1                    Two woman are holding packages.      0
# 2               The men are fighting outside a deli.      2
# 3     Two kids in numbered jerseys wash their hands.      0
# 4           Two kids at a ballgame wash their hands.      1
#
#                                     predicted_scores  predicted_label
# 0  [-4.015252590179443, 4.470546245574951, -1.911...                1
# 1  [2.888674736022949, -2.042037963867187, -0.795...                0
# 2  [-4.105733871459961, -1.17663288116455, 3.9173...                2
# 3  [1.355234861373901, -2.21549916267395, 1.08333...                0
# 4  [-2.860575914382934, -2.119940996170044, 3.986...                2

# %%
import pandas as pd

# Assuming df_base and df_a1 are your DataFrames

# Step 1: Merge the DataFrames on 'premise' and 'hypothesis'
merged_df = pd.merge(df_base, df_a1, on=['premise', 'hypothesis'], suffixes=('_base', '_a1'))

# Step 2: Filter rows where label matches predicted_label in df_base but not in df_a1
filtered_df = merged_df[
    (merged_df['label_base'] == merged_df['predicted_label_base']) &
    (merged_df['label_a1'] != merged_df['predicted_label_a1'])
]

# Step 3: Selecting relevant columns (optional)
# You can modify this list to include the columns you're interested in
columns_to_display = ['premise', 'hypothesis', 'label_base', 'predicted_label_base', 'label_a1', 'predicted_label_a1']
result_df = filtered_df[columns_to_display]

# Display the result
result_df
# Out:
#                                                 premise  \
# 4     Two young children in blue jerseys, one with t...
# 10    Two young boys of opposing teams play football...
# 23             Two men on bicycles competing in a race.
# 27    Families waiting in line at an amusement park ...
# 39    At an outdoor event in an Asian-themed area, a...
# ...                                                 ...
# 9794  Two children in a bag race competing against e...
# 9803  A view from a hidden camera at a low height sh...
# 9813      Three young indian children play wiffle ball.
# 9815  A group of people is gathered around a table o...
# 9830  Two police officers are sitting on motorcycles...
#
#                                              hypothesis  label_base  \
# 4              Two kids at a ballgame wash their hands.           1
# 10                                 dog eats out of bowl           2
# 23                      A few people are catching fish.           2
# 27                          The restaurant is very bad.           2
# 39                     A single man is next to a camera           2
# ...                                                 ...         ...
# 9794                          There are three children.           0
# 9803  A husband and wife enjoy their wedding in a ch...           2
# 9813                         Three children are crying.           2
# 9815  A group of people are gather around a meeting ...           1
# 9830                              the police are sleep.           2
#
#       predicted_label_base  label_a1  predicted_label_a1
# 4                        1         1                   2
# 10                       2         2                   1
# 23                       2         2                   1
# 27                       2         2                   1
# 39                       2         2                   1
# ...                    ...       ...                 ...
# 9794                     0         0                   2
# 9803                     2         2                   1
# 9813                     2         2                   1
# 9815                     1         1                   2
# 9830                     2         2                   1
#
# [1039 rows x 6 columns]

# %%
len(result_df)
# Out:
# 1039

# %%
# Filter result_df based on specific conditions
final_df = result_df[
    (result_df['label_base'] == 1) &
    (result_df['predicted_label_base'] == 1) &
    (result_df['predicted_label_a1'] == 0)
]

# Display the final DataFrame
final_df
# Out:
#                                                 premise  \
# 223   An asian woman sitting outside an outdoor mark...
# 297   A goalie in white runs for an approaching ball...
# 490       Five people are sitting on horses at a rodeo.
# 587   A boy walking away from two Camden tents with ...
# 705   Three children play with a giant sphere on a p...
# ...                                                 ...
# 9314  A woman in a college t-shirt walking quickly c...
# 9351  Four cheerleaders performing a cheer on court ...
# 9496        Golfer celebrates after a shot he has made.
# 9739  A little girl in a red and white shirt stands ...
# 9748  Two boys, one wearing green, the other in yell...
#
#                                              hypothesis  label_base  \
# 223          A woman is selling stuff in a flea market.           1
# 297   The goalie is running out to catch the ball be...           1
# 490           A group of cowboys are sitting on horses.           1
# 587            A person leaving a tent with his friends           1
# 705   A group of children are playing while their te...           1
# ...                                                 ...         ...
# 9314                A college student is carrying bags.           1
# 9351             Cheerleaders cheering at a tournament.           1
# 9496  A golfer is competing in an important tournament.           1
# 9739                       a kid stands near modern art           1
# 9748  There are two boys drawing lewd pictures in ch...           1
#
#       predicted_label_base  label_a1  predicted_label_a1
# 223                      1         1                   0
# 297                      1         1                   0
# 490                      1         1                   0
# 587                      1         1                   0
# 705                      1         1                   0
# ...                    ...       ...                 ...
# 9314                     1         1                   0
# 9351                     1         1                   0
# 9496                     1         1                   0
# 9739                     1         1                   0
# 9748                     1         1                   0
#
# [89 rows x 6 columns]

# %%
len(final_df)/len(result_df)
# Out:
# 0.08565928777670838

# %%
# Filter result_df based on specific conditions
final_df = result_df[
    (result_df['label_base'] == 1) &
    (result_df['predicted_label_base'] == 1) &
    (result_df['predicted_label_a1'] == 2)
]

# Display the final DataFrame
final_df
len(final_df)/len(result_df)
# Out:
# 0.12800769971126083

# %%
# Filter result_df based on specific conditions
final_df = result_df[
    (result_df['label_base'] == 2) &
    (result_df['predicted_label_base'] == 2) &
    (result_df['predicted_label_a1'] == 0)
]

# Display the final DataFrame
final_df
#len(final_df)/len(result_df)
# Out:
#                                                 premise  \
# 233   Number 13 kicks a soccer ball towards the goal...
# 745   A man with black pants on walks by a wall with...
# 1834  A man with shoulder length dark hair sits near...
# 1871  A sports match is taking place between one tea...
# 2491  A young woman tennis player dressed in black c...
# 4008                       The dog is catching a treat.
# 4188  An elderly man sleeping in a outdoor chair whi...
# 4250  A man walking in front of a black cement wall ...
# 4315  A man wearing a top-hat, blue plaid pajama pan...
# 6179  A man in a black shirt sits beneath a'no child...
# 6306  A gathering of young African males under a tha...
# 6826  A group of men are playing rugby in a field wi...
# 6911  A little boy wearing glasses and a t-shirt tha...
# 7661  A boy wearing a black shirt is playing a game ...
# 7879  A man wearing a U.S. Navy uniform and a woman ...
# 8201  Scene from a life show with man singing in the...
# 8220          A female is looking through a microscope.
# 9776  During this vacation children enjoying their g...
#
#                                              hypothesis  label_base  \
# 233                 A player fighting in a soccer game.           2
# 745                            A man is in outer space.           2
# 1834                      A bald man holds a cigarette.           2
# 1871   Two teams are refusing to play each other naked.           2
# 2491             A young woman never wears white dress.           2
# 4008                    the cat is not catching a treat           2
# 4188                    Two women are relaxing outside.           2
# 4250                           A man is in outer space.           2
# 4315                            A man has on a sombrero           2
# 6179  The man sitting beneath the presentation had n...           2
# 6306             A group of men are standing on a roof.           2
# 6826                        The men are at a sports bar           2
# 6911                         Two kids riding a see-saw.           2
# 7661                             A kid is in the field.           2
# 7879                Two people excitedly watch an event           2
# 8201                   A man is sitting in an audience.           2
# 8220                  A lady poked her eye with needles           2
# 9776                                  The kids are home           2
#
#       predicted_label_base  label_a1  predicted_label_a1
# 233                      2         2                   0
# 745                      2         2                   0
# 1834                     2         2                   0
# 1871                     2         2                   0
# 2491                     2         2                   0
# 4008                     2         2                   0
# 4188                     2         2                   0
# 4250                     2         2                   0
# 4315                     2         2                   0
# 6179                     2         2                   0
# 6306                     2         2                   0
# 6826                     2         2                   0
# 6911                     2         2                   0
# 7661                     2         2                   0
# 7879                     2         2                   0
# 8201                     2         2                   0
# 8220                     2         2                   0
# 9776                     2         2                   0

# %%
len(final_df)/len(result_df)
# Out:
# 0.017324350336862367

# %%
# Filter result_df based on specific conditions
final_df = result_df[
    (result_df['label_base'] == 2) &
    (result_df['predicted_label_base'] == 2) &
    (result_df['predicted_label_a1'] == 1)
]

# Display the final DataFrame
final_df
len(final_df)/len(result_df)
# Out:
# 0.4542829643888354

# %%
# Filter result_df based on specific conditions
final_df = result_df[
    (result_df['label_base'] == 0) &
    (result_df['predicted_label_base'] == 0) &
    (result_df['predicted_label_a1'] == 2)
]

# Display the final DataFrame
final_df
len(final_df)/len(result_df)
# Out:
# 0.14918190567853706

# %%
# Filter result_df based on specific conditions
final_df = result_df[
    (result_df['label_base'] == 0) &
    (result_df['predicted_label_base'] == 0) &
    (result_df['predicted_label_a1'] == 1)
]

# Display the final DataFrame
final_df
#len(final_df)/len(result_df)
# Out:
#                                                 premise  \
# 86    The two farmers are working on a piece of John...
# 117   A person powerwashing stairs leading down to a...
# 128   A group of people prepare hot air balloons for...
# 232   Number 13 kicks a soccer ball towards the goal...
# 261   A man is a safety suit walking outside while a...
# ...                                                 ...
# 9461    The lady wearing a red coat is giving a speech.
# 9465  A nurse examines equipment in the operating room.
# 9542  A boy and dog are on the lawn outside of the h...
# 9613  A soldier is holding a gun and crouched down w...
# 9657  Two competitors in the last leg of a race, str...
#
#                                       hypothesis  label_base  \
# 86       Men are working on John Deere equipment           0
# 117                a worker cleans near the pool           0
# 128               A group of people are outside.           0
# 232   A player trying to score in a soccer game.           0
# 261           There are two men walking outside.           0
# ...                                          ...         ...
# 9461           Woman is the center of attention.           0
# 9465                            A nurse at work.           0
# 9542                 A boy and dog play outside.           0
# 9613                     A man is holding a gun.           0
# 9657               Races can be long and tiring.           0
#
#       predicted_label_base  label_a1  predicted_label_a1
# 86                       0         0                   1
# 117                      0         0                   1
# 128                      0         0                   1
# 232                      0         0                   1
# 261                      0         0                   1
# ...                    ...       ...                 ...
# 9461                     0         0                   1
# 9465                     0         0                   1
# 9542                     0         0                   1
# 9613                     0         0                   1
# 9657                     0         0                   1
#
# [172 rows x 6 columns]

# %%
len(final_df)/len(result_df)
# Out:
# 0.16554379210779596
